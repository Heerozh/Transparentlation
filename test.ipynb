# %%
import inspect


frame = inspect.currentframe().f_back

# %%
# %%timeit
frame = inspect.currentframe().f_back
# Out:
# 55.7 ns ± 0.954 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
(frame.f_code.co_filename, frame.f_lasti)
# Out:
# 33.8 ns ± 0.548 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
from babel import Locale
locale = Locale('es')
locale
